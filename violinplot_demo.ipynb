# %%
import numpy as np
import matplotlib.pyplot as plt
from freeplot.base import FreePlot

# %%
fp = FreePlot((1, 1), (5, 5))

# %%
all_data = [np.random.normal(0, std, 100) for std in range(5, 10)]
fp.violinplot(x=['a', 'b', 'c', 'd', 'e'], y=all_data, index=0)

# %%
fp.fig
